# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from pathlib import Path

np.random.seed(42) #Uczyńmy wyniki notatnika stabilnymi

# domyslne rozmiary czcionek

plt.rc("font", size=12)
plt.rc("axes", labelsize=14, titlesize=14)
plt.rc("legend", fontsize =12)
plt.rc("xtick", labelsize=10)
plt.rc("ytick", labelsize=10)

# Zdefiniujmy ustawienia biblioteki Pandas
pd.set_option("display.max_columns", None) # wyświetlaj wszstkie kolumny w
# pd.set_option("display.max_rows", None) # Wyświetlaj wszystkie wiersze
pd.set_option("display.max_colwidth", None) # Maks szerokosc kolumny
pd.set_option("display.precision", 2) # Zdefiniuj precyzje wyświetlania liczb
pd.reset_option("display.max_rows") # Skopiuj i odkomentuj aby zresetowac

# %%
datapath = Path() /"data"/"lifesat" # Definiujemy ścieżkę do bieżącego katalogu

# Wczytujemy zbiory
oecd_bli = pd.read_csv(datapath/"oecd_bli.csv")
gdp_per_capita = pd.read_csv(datapath / "gdp_per_capita.csv")

# %%
oecd_bli
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2364      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2365      COL        Colombia   WL_EWLH  Employees working very long hours
# 2366      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2367      COL        Colombia   WL_EWLH  Employees working very long hours
# 2368      LTU       Lithuania   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# ...

# %%
gdp_per_capita
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2002
# 1     Afghanistan  AFG  2003
# 2     Afghanistan  AFG  2004
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2006
# ...           ...  ...   ...
# 7104     Zimbabwe  ZWE  2016
# 7105     Zimbabwe  ZWE  2017
# 7106     Zimbabwe  ZWE  2018
# 7107     Zimbabwe  ZWE  2019
# 7108     Zimbabwe  ZWE  2020
#
#       GDP per capita, PPP (constant 2017 international $)
# 0                                                 1189.78
# 1                                                 1235.81
# 2                                                 1200.28
# 3                                                 1286.79
# 4                                                 1315.79
# ...                                                   ...
# 7104                                              3173.61
# 7105                                              3274.61
# 7106                                              3341.67
# ...

# %%
gdp_per_capita_2020 = gdp_per_capita[gdp_per_capita["Year"]==2020]
gdp_per_capita_2020 = gdp_per_capita_2020.rename(
    columns={
      "GDP per capita, PPP (constant 2017 international $)": "GDP per capita (USD)"
    }
)
gdp_per_capita_2020
# Out:
#                            Entity      Code  Year  GDP per capita (USD)
# 18                    Afghanistan       AFG  2020               1978.96
# 49    Africa Eastern and Southern       NaN  2020               3387.59
# 80     Africa Western and Central       NaN  2020               4003.16
# 111                       Albania       ALB  2020              13295.41
# 142                       Algeria       DZA  2020              10681.68
# ...                           ...       ...   ...                   ...
# 6984                      Vanuatu       VUT  2020               2762.79
# 7015                      Vietnam       VNM  2020               8200.33
# 7046                        World  OWID_WRL  2020              16194.04
# 7077                       Zambia       ZMB  2020               3270.04
# 7108                     Zimbabwe       ZWE  2020               2744.69
#
# [224 rows x 4 columns]

# %%
oecd_bli["Indicator"].value_counts()
# Out:
# Indicator
# Student skills                                       200
# Self-reported health                                 182
# Quality of support network                           168
# Life satisfaction                                    168
# Labour market insecurity                             162
# Homicide rate                                        123
# Feeling safe walking alone at night                  123
# Life expectancy                                      123
# Water quality                                        123
# Employment rate                                      123
# Years in education                                   120
# Educational attainment                               120
# Long-term unemployment rate                          117
# Employees working very long hours                    117
# Time devoted to leisure and personal care             69
# Air pollution                                         41
# ...

# %%
# Pivot table

oecd_bli = oecd_bli[oecd_bli["INEQUALITY"] == "TOT"]
oecd_bli = oecd_bli.pivot(
    index="Country",
    columns="Indicator",
    values="Value",
)
oecd_bli
# Out:
# Indicator        Air pollution  Dwellings without basic facilities  \
# Country
# Australia                  5.0                                 NaN
# Austria                   16.0                                 0.9
# Belgium                   15.0                                 1.9
# Brazil                    10.0                                 6.7
# Canada                     7.0                                 0.2
# Chile                     16.0                                 9.4
# Colombia                  10.0                                23.9
# Czech Republic            20.0                                 0.7
# Denmark                    9.0                                 0.5
# Estonia                    8.0                                 7.0
# Finland                    6.0                                 0.5
# France                    13.0                                 0.5
# Germany                   14.0                                 0.2
# ...

# %%
# Resetowanie indeksu
oecd_bli = oecd_bli.reset_index()
oecd_bli
# Out:
# Indicator          Country  Air pollution  Dwellings without basic facilities  \
# 0                Australia            5.0                                 NaN
# 1                  Austria           16.0                                 0.9
# 2                  Belgium           15.0                                 1.9
# 3                   Brazil           10.0                                 6.7
# 4                   Canada            7.0                                 0.2
# 5                    Chile           16.0                                 9.4
# 6                 Colombia           10.0                                23.9
# 7           Czech Republic           20.0                                 0.7
# 8                  Denmark            9.0                                 0.5
# 9                  Estonia            8.0                                 7.0
# 10                 Finland            6.0                                 0.5
# ...

# %%
gdp_per_capita_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 224 entries, 18 to 7108
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                224 non-null    object
#  1   Code                  179 non-null    object
#  2   Year                  224 non-null    int64
#  3   GDP per capita (USD)  224 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.8+ KB

# %%
full_country_stats = oecd_bli.merge(    
    gdp_per_capita_2020,
    left_on= "Country",
    right_on= "Entity",
    how="inner"
)
full_country_stats
# Out:
#            Country  Air pollution  Dwellings without basic facilities  \
# 0        Australia            5.0                                 NaN
# 1          Austria           16.0                                 0.9
# 2          Belgium           15.0                                 1.9
# 3           Brazil           10.0                                 6.7
# 4           Canada            7.0                                 0.2
# 5            Chile           16.0                                 9.4
# 6         Colombia           10.0                                23.9
# 7          Denmark            9.0                                 0.5
# 8          Estonia            8.0                                 7.0
# 9          Finland            6.0                                 0.5
# 10          France           13.0                                 0.5
# 11         Germany           14.0                                 0.2
# ...

# %%
# Ograniczamy kolumny

full_country_stats= full_country_stats[[
    "Country", "Life satisfaction", "GDP per capita (USD)"
]]
full_country_stats = full_country_stats.sort_values(
    by= "GDP per capita (USD)",
    ascending= False
)
full_country_stats
# Out:
#            Country  Life satisfaction  GDP per capita (USD)
# 20      Luxembourg                6.9             110261.16
# 15         Ireland                7.0              89688.96
# 32     Switzerland                7.5              68393.31
# 24          Norway                7.6              63585.90
# 35   United States                6.9              60235.73
# 7          Denmark                7.6              55938.21
# 22     Netherlands                7.4              54209.56
# 14         Iceland                7.5              52279.73
# 1          Austria                7.1              51935.60
# 11         Germany                7.0              50922.36
# 31          Sweden                7.3              50683.32
# 0        Australia                7.3              48697.84
# 2          Belgium                6.9              48210.03
# 9          Finland                7.6              47260.80
# 4           Canada                7.4              45856.63
# ...

# %%
full_country_stats.to_csv(
    datapath / "livesat_full.csv",
    index=False
)

# %%
min_gdp = 23500
max_gdp = 62500

country_stats = full_country_stats[
    (full_country_stats["GDP per capita (USD)"] >= min_gdp)
    & (full_country_stats["GDP per capita (USD)"] <= max_gdp)
]
country_stats.to_csv(
    datapath / "lifesat.csv",
    index=False
)
